# %% [markdown]
# # Web Scraping with Heroku Deployment

# %% [markdown]
# ## 1. Heroku

# %% [markdown]
# ![](Heroku.jpg)![Heroku.png](attachment:Heroku.png)

# %% [markdown]
# ## 2. Web Scraping

# %% [markdown]
# ![Web%20Scraping.png](attachment:Web%20Scraping.png)
